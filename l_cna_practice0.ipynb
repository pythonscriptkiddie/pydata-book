# %%
import numpy as np
import pandas as pd

# %%
raw_df_step0 = pd.read_csv('stock_data/l_cna_2018_2022.csv', index_col=[0],
                           header=[0, 1], skipinitialspace=True)

# %%
#l_premium = raw_df_step0[]

# %%
l_premium_adj = raw_df_step0['Close']['L'] - raw_df_step0['Adj Close']['CNA']

# %%
raw_df_step0 = raw_df_step0.assign(**{'Loews (L) premium': l_premium_adj})

# %%
raw_df_step0
# Out:
#                            Adj Close                 Close             \
#                                  CNA          L        CNA          L
# Date
# 2018-01-02 00:00:00-05:00  36.725540  48.644119  52.419998  49.889999
# 2018-01-03 00:00:00-05:00  36.900681  49.209652  52.669998  50.470001
# 2018-01-04 00:00:00-05:00  37.159912  49.453403  53.040001  50.720001
# 2018-01-05 00:00:00-05:00  37.166912  49.355900  53.049999  50.619999
# 2018-01-08 00:00:00-05:00  36.963741  49.316902  52.759998  50.580002
# ...                              ...        ...        ...        ...
# 2023-01-27 00:00:00-05:00  43.150002  60.990002  43.150002  60.990002
# 2023-01-30 00:00:00-05:00  43.000000  60.419998  43.000000  60.419998
# 2023-01-31 00:00:00-05:00  43.560001  61.480000  43.560001  61.480000
# 2023-02-01 00:00:00-05:00  42.660000  60.540001  42.660000  60.540001
# 2023-02-02 00:00:00-05:00  41.740002  60.180000  41.740002  60.180000
#
# ...
